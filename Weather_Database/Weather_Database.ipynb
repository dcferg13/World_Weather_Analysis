# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the print() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
    
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather ["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": weather_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | marawi
# Processing Record 2 of Set 1 | klaksvik
# Processing Record 3 of Set 1 | vila franca do campo
# Processing Record 4 of Set 1 | broken hill
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | vitim
# Processing Record 7 of Set 1 | san vicente
# Processing Record 8 of Set 1 | wahran
# City not found. Skipping...
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | provideniya
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | san carlos de bariloche
# Processing Record 13 of Set 1 | nantucket
# Processing Record 14 of Set 1 | ribeira grande
# Processing Record 15 of Set 1 | geraldton
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | isangel
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | tiksi
# Processing Record 20 of Set 1 | hambantota
# Processing Record 21 of Set 1 | novokizhinginsk
# Processing Record 22 of Set 1 | naustdal
# Processing Record 23 of Set 1 | atuona
# Processing Record 24 of Set 1 | vao
# Processing Record 25 of Set 1 | salalah
# Processing Record 26 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | kavieng
# Processing Record 29 of Set 1 | bandarbeyla
# Processing Record 30 of Set 1 | bellingham
# Processing Record 31 of Set 1 | narsaq
# Processing Record 32 of Set 1 | roma
# Processing Record 33 of Set 1 | mutsamudu
# City not found. Skipping...
# Processing Record 34 of Set 1 | ponta do sol
# Processing Record 35 of Set 1 | norman wells
# Processing Record 36 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 37 of Set 1 | barrow
# Processing Record 38 of Set 1 | georgetown
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | oistins
# Processing Record 41 of Set 1 | rikitea
# Processing Record 42 of Set 1 | carnarvon
# Processing Record 43 of Set 1 | mataura
# Processing Record 44 of Set 1 | tuscaloosa
# Processing Record 45 of Set 1 | taltal
# Processing Record 46 of Set 1 | vardo
# Processing Record 47 of Set 1 | inta
# Processing Record 48 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 1 | esperance
# Processing Record 50 of Set 1 | hithadhoo
# Processing Record 1 of Set 2 | krasnogorsk
# Processing Record 2 of Set 2 | bar harbor
# Processing Record 3 of Set 2 | saint-philippe
# Processing Record 4 of Set 2 | menongue
# Processing Record 5 of Set 2 | pisco
# Processing Record 6 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 2 | chuy
# Processing Record 8 of Set 2 | aswan
# Processing Record 9 of Set 2 | qaanaaq
# Processing Record 10 of Set 2 | ancud
# Processing Record 11 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 2 | jiddah
# City not found. Skipping...
# Processing Record 15 of Set 2 | lavrentiya
# Processing Record 16 of Set 2 | fort portal
# Processing Record 17 of Set 2 | avarua
# Processing Record 18 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 2 | ushtobe
# Processing Record 20 of Set 2 | kapaa
# Processing Record 21 of Set 2 | mayya
# Processing Record 22 of Set 2 | asosa
# Processing Record 23 of Set 2 | gweta
# Processing Record 24 of Set 2 | saint-pierre
# Processing Record 25 of Set 2 | kerema
# Processing Record 26 of Set 2 | lebu
# Processing Record 27 of Set 2 | aklavik
# Processing Record 28 of Set 2 | sao filipe
# Processing Record 29 of Set 2 | santa isabel do rio negro
# Processing Record 30 of Set 2 | comodoro rivadavia
# Processing Record 31 of Set 2 | abeche
# Processing Record 32 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 33 of Set 2 | hilo
# Processing Record 34 of Set 2 | mildura
# Processing Record 35 of Set 2 | evanston
# Processing Record 36 of Set 2 | thompson
# Processing Record 37 of Set 2 | cabo san lucas
# Processing Record 38 of Set 2 | codrington
# Processing Record 39 of Set 2 | raahe
# Processing Record 40 of Set 2 | kaitangata
# Processing Record 41 of Set 2 | corpus christi
# Processing Record 42 of Set 2 | avera
# Processing Record 43 of Set 2 | samarinda
# Processing Record 44 of Set 2 | bose
# Processing Record 45 of Set 2 | port alfred
# Processing Record 46 of Set 2 | castro
# Processing Record 47 of Set 2 | bur gabo
# City not found. Skipping...
# Processing Record 48 of Set 2 | port elizabeth
# Processing Record 49 of Set 2 | kadykchan
# City not found. Skipping...
# Processing Record 50 of Set 2 | mokhsogollokh
# Processing Record 1 of Set 3 | dikson
# Processing Record 2 of Set 3 | mahebourg
# Processing Record 3 of Set 3 | mar del plata
# Processing Record 4 of Set 3 | sistranda
# Processing Record 5 of Set 3 | saskylakh
# Processing Record 6 of Set 3 | vaini
# Processing Record 7 of Set 3 | el colomo
# Processing Record 8 of Set 3 | centralia
# Processing Record 9 of Set 3 | severo-kurilsk
# Processing Record 10 of Set 3 | puerto ayora
# Processing Record 11 of Set 3 | saint george
# Processing Record 12 of Set 3 | santa maria
# Processing Record 13 of Set 3 | riyadh
# Processing Record 14 of Set 3 | saint-augustin
# Processing Record 15 of Set 3 | panama city
# Processing Record 16 of Set 3 | igarka
# Processing Record 17 of Set 3 | monroe
# Processing Record 18 of Set 3 | jamestown
# Processing Record 19 of Set 3 | lac du bonnet
# Processing Record 20 of Set 3 | butaritari
# Processing Record 21 of Set 3 | yellowknife
# Processing Record 22 of Set 3 | necochea
# Processing Record 23 of Set 3 | balabac
# Processing Record 24 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 3 | joshimath
# Processing Record 26 of Set 3 | yumen
# Processing Record 27 of Set 3 | khatanga
# Processing Record 28 of Set 3 | saldanha
# Processing Record 29 of Set 3 | katsuura
# Processing Record 30 of Set 3 | alcaniz
# Processing Record 31 of Set 3 | arraial do cabo
# Processing Record 32 of Set 3 | upernavik
# Processing Record 33 of Set 3 | east london
# Processing Record 34 of Set 3 | hanna
# Processing Record 35 of Set 3 | caravelas
# Processing Record 36 of Set 3 | hobart
# Processing Record 37 of Set 3 | guayaramerin
# Processing Record 38 of Set 3 | matagami
# Processing Record 39 of Set 3 | stoyba
# City not found. Skipping...
# Processing Record 40 of Set 3 | americus
# Processing Record 41 of Set 3 | kaeo
# Processing Record 42 of Set 3 | los llanos de aridane
# Processing Record 43 of Set 3 | bredasdorp
# Processing Record 44 of Set 3 | palmer
# Processing Record 45 of Set 3 | umm lajj
# Processing Record 46 of Set 3 | myaundzha
# Processing Record 47 of Set 3 | faridan
# City not found. Skipping...
# Processing Record 48 of Set 3 | moses lake
# Processing Record 49 of Set 3 | san patricio
# Processing Record 50 of Set 3 | townsville
# Processing Record 1 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 3 of Set 4 | parkersburg
# Processing Record 4 of Set 4 | tasiilaq
# Processing Record 5 of Set 4 | nelson bay
# Processing Record 6 of Set 4 | ballina
# Processing Record 7 of Set 4 | college
# Processing Record 8 of Set 4 | kondoa
# Processing Record 9 of Set 4 | new norfolk
# Processing Record 10 of Set 4 | orizona
# Processing Record 11 of Set 4 | kem
# Processing Record 12 of Set 4 | nouadhibou
# Processing Record 13 of Set 4 | phangnga
# Processing Record 14 of Set 4 | ternate
# Processing Record 15 of Set 4 | dukat
# Processing Record 16 of Set 4 | lewistown
# Processing Record 17 of Set 4 | khandyga
# Processing Record 18 of Set 4 | terney
# Processing Record 19 of Set 4 | abu dhabi
# Processing Record 20 of Set 4 | acarau
# Processing Record 21 of Set 4 | strezhevoy
# Processing Record 22 of Set 4 | dingle
# Processing Record 23 of Set 4 | nemuro
# Processing Record 24 of Set 4 | cockburn town
# Processing Record 25 of Set 4 | kahului
# Processing Record 26 of Set 4 | suoyarvi
# Processing Record 27 of Set 4 | touros
# Processing Record 28 of Set 4 | ust-nera
# Processing Record 29 of Set 4 | kodiak
# Processing Record 30 of Set 4 | waipawa
# Processing Record 31 of Set 4 | cayenne
# Processing Record 32 of Set 4 | maningrida
# Processing Record 33 of Set 4 | pingliang
# Processing Record 34 of Set 4 | clyde river
# Processing Record 35 of Set 4 | hasaki
# Processing Record 36 of Set 4 | zhezkazgan
# Processing Record 37 of Set 4 | tuktoyaktuk
# Processing Record 38 of Set 4 | vostok
# Processing Record 39 of Set 4 | tabas
# Processing Record 40 of Set 4 | ishigaki
# Processing Record 41 of Set 4 | rudnogorsk
# Processing Record 42 of Set 4 | bam
# Processing Record 43 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 4 | nyurba
# Processing Record 45 of Set 4 | darhan
# Processing Record 46 of Set 4 | gympie
# Processing Record 47 of Set 4 | kimbe
# Processing Record 48 of Set 4 | chemainus
# Processing Record 49 of Set 4 | urumqi
# Processing Record 50 of Set 4 | naze
# Processing Record 1 of Set 5 | sao jose da coroa grande
# Processing Record 2 of Set 5 | sinnamary
# Processing Record 3 of Set 5 | quatre cocos
# Processing Record 4 of Set 5 | victoria
# Processing Record 5 of Set 5 | porto seguro
# Processing Record 6 of Set 5 | belogorsk
# Processing Record 7 of Set 5 | viedma
# Processing Record 8 of Set 5 | cherskiy
# Processing Record 9 of Set 5 | ayan
# Processing Record 10 of Set 5 | marsa matruh
# Processing Record 11 of Set 5 | ndele
# Processing Record 12 of Set 5 | matay
# Processing Record 13 of Set 5 | omboue
# Processing Record 14 of Set 5 | mount gambier
# Processing Record 15 of Set 5 | longyearbyen
# Processing Record 16 of Set 5 | chokurdakh
# Processing Record 17 of Set 5 | tibati
# Processing Record 18 of Set 5 | lorengau
# Processing Record 19 of Set 5 | nara
# Processing Record 20 of Set 5 | gobabis
# Processing Record 21 of Set 5 | lichinga
# Processing Record 22 of Set 5 | atherton
# Processing Record 23 of Set 5 | broome
# Processing Record 24 of Set 5 | lompoc
# Processing Record 25 of Set 5 | la uribe
# City not found. Skipping...
# Processing Record 26 of Set 5 | luebo
# Processing Record 27 of Set 5 | kirakira
# Processing Record 28 of Set 5 | tehri
# Processing Record 29 of Set 5 | boca do acre
# Processing Record 30 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 31 of Set 5 | morada nova
# Processing Record 32 of Set 5 | guerrero negro
# Processing Record 33 of Set 5 | san quintin
# Processing Record 34 of Set 5 | airai
# Processing Record 35 of Set 5 | half moon bay
# Processing Record 36 of Set 5 | fexhe-le-haut-clocher
# Processing Record 37 of Set 5 | barreiras
# Processing Record 38 of Set 5 | bambous virieux
# Processing Record 39 of Set 5 | iqaluit
# Processing Record 40 of Set 5 | leningradskiy
# Processing Record 41 of Set 5 | whitehorse
# Processing Record 42 of Set 5 | bassano
# Processing Record 43 of Set 5 | coihaique
# Processing Record 44 of Set 5 | hovd
# Processing Record 45 of Set 5 | mehamn
# Processing Record 46 of Set 5 | mackenzie
# Processing Record 47 of Set 5 | tura
# Processing Record 48 of Set 5 | bilibino
# Processing Record 49 of Set 5 | bengkulu
# Processing Record 50 of Set 5 | ferme-neuve
# Processing Record 1 of Set 6 | charagua
# Processing Record 2 of Set 6 | okhotsk
# Processing Record 3 of Set 6 | revelstoke
# Processing Record 4 of Set 6 | kuloy
# Processing Record 5 of Set 6 | bethel
# Processing Record 6 of Set 6 | kinablangan
# Processing Record 7 of Set 6 | surt
# Processing Record 8 of Set 6 | bambanglipuro
# Processing Record 9 of Set 6 | ekhabi
# Processing Record 10 of Set 6 | dakar
# Processing Record 11 of Set 6 | camacha
# Processing Record 12 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 13 of Set 6 | gemena
# Processing Record 14 of Set 6 | san cristobal
# Processing Record 15 of Set 6 | monte alegre
# Processing Record 16 of Set 6 | hounde
# Processing Record 17 of Set 6 | vanimo
# Processing Record 18 of Set 6 | tabulbah
# City not found. Skipping...
# Processing Record 19 of Set 6 | manzhouli
# Processing Record 20 of Set 6 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 21 of Set 6 | galesong
# Processing Record 22 of Set 6 | talakan
# Processing Record 23 of Set 6 | touba
# Processing Record 24 of Set 6 | karratha
# Processing Record 25 of Set 6 | pucallpa
# Processing Record 26 of Set 6 | kabansk
# Processing Record 27 of Set 6 | verkhnyaya inta
# Processing Record 28 of Set 6 | uwajima
# Processing Record 29 of Set 6 | pacific grove
# Processing Record 30 of Set 6 | banff
# Processing Record 31 of Set 6 | san jose
# Processing Record 32 of Set 6 | bitung
# Processing Record 33 of Set 6 | trorod
# Processing Record 34 of Set 6 | tiznit
# Processing Record 35 of Set 6 | amot
# Processing Record 36 of Set 6 | yar-sale
# Processing Record 37 of Set 6 | waingapu
# Processing Record 38 of Set 6 | santa rosalia
# Processing Record 39 of Set 6 | cururupu
# Processing Record 40 of Set 6 | mao
# Processing Record 41 of Set 6 | bealanana
# Processing Record 42 of Set 6 | upata
# Processing Record 43 of Set 6 | namibe
# Processing Record 44 of Set 6 | ust-ishim
# Processing Record 45 of Set 6 | colombia
# Processing Record 46 of Set 6 | cidreira
# Processing Record 47 of Set 6 | ilulissat
# Processing Record 48 of Set 6 | eureka
# Processing Record 49 of Set 6 | buin
# Processing Record 50 of Set 6 | kushima
# Processing Record 1 of Set 7 | carutapera
# Processing Record 2 of Set 7 | lincoln
# Processing Record 3 of Set 7 | silver city
# Processing Record 4 of Set 7 | zhengjiatun
# Processing Record 5 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 7 | wanaka
# Processing Record 7 of Set 7 | oussouye
# Processing Record 8 of Set 7 | gurgan
# City not found. Skipping...
# Processing Record 9 of Set 7 | akdepe
# Processing Record 10 of Set 7 | katangli
# Processing Record 11 of Set 7 | ornskoldsvik
# Processing Record 12 of Set 7 | gambela
# Processing Record 13 of Set 7 | ust-tsilma
# Processing Record 14 of Set 7 | seoul
# Processing Record 15 of Set 7 | constitucion
# Processing Record 16 of Set 7 | reoti
# Processing Record 17 of Set 7 | barbastro
# Processing Record 18 of Set 7 | buchanan
# Processing Record 19 of Set 7 | fort saint john
# City not found. Skipping...
# Processing Record 20 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 7 | velika kladusa
# Processing Record 22 of Set 7 | nome
# Processing Record 23 of Set 7 | karakendzha
# City not found. Skipping...
# Processing Record 24 of Set 7 | pevek
# Processing Record 25 of Set 7 | thinadhoo
# Processing Record 26 of Set 7 | cooma
# Processing Record 27 of Set 7 | cangzhou
# Processing Record 28 of Set 7 | ketchikan
# Processing Record 29 of Set 7 | gilgit
# Processing Record 30 of Set 7 | mitsamiouli
# Processing Record 31 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 7 | desaguadero
# Processing Record 33 of Set 7 | mezen
# Processing Record 34 of Set 7 | belmonte
# Processing Record 35 of Set 7 | faanui
# Processing Record 36 of Set 7 | victor harbor
# Processing Record 37 of Set 7 | slobodskoy
# Processing Record 38 of Set 7 | jasper
# Processing Record 39 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 7 | serpa
# Processing Record 41 of Set 7 | nizwa
# Processing Record 42 of Set 7 | mareeba
# Processing Record 43 of Set 7 | general roca
# Processing Record 44 of Set 7 | wajir
# Processing Record 45 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 46 of Set 7 | oranjestad
# Processing Record 47 of Set 7 | ormara
# Processing Record 48 of Set 7 | sobolevo
# Processing Record 49 of Set 7 | flinders
# Processing Record 50 of Set 7 | lamu
# Processing Record 1 of Set 8 | gat
# Processing Record 2 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 3 of Set 8 | zhanaozen
# Processing Record 4 of Set 8 | gwanda
# Processing Record 5 of Set 8 | rouvroy
# Processing Record 6 of Set 8 | kloulklubed
# Processing Record 7 of Set 8 | kalmunai
# Processing Record 8 of Set 8 | alofi
# Processing Record 9 of Set 8 | gallipoli
# Processing Record 10 of Set 8 | camapua
# Processing Record 11 of Set 8 | flin flon
# Processing Record 12 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 13 of Set 8 | zharkent
# Processing Record 14 of Set 8 | diffa
# Processing Record 15 of Set 8 | port lincoln
# Processing Record 16 of Set 8 | tres lagoas
# Processing Record 17 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 8 | straumen
# Processing Record 19 of Set 8 | acapulco
# Processing Record 20 of Set 8 | brae
# Processing Record 21 of Set 8 | mincivan
# Processing Record 22 of Set 8 | buluang
# Processing Record 23 of Set 8 | pontianak
# Processing Record 24 of Set 8 | kulhudhuffushi
# Processing Record 25 of Set 8 | abilene
# Processing Record 26 of Set 8 | homer
# Processing Record 27 of Set 8 | korla
# Processing Record 28 of Set 8 | aksu
# Processing Record 29 of Set 8 | opuwo
# Processing Record 30 of Set 8 | hokitika
# Processing Record 31 of Set 8 | saint-joseph
# Processing Record 32 of Set 8 | nanortalik
# Processing Record 33 of Set 8 | srednekolymsk
# Processing Record 34 of Set 8 | saint anthony
# Processing Record 35 of Set 8 | obo
# Processing Record 36 of Set 8 | miri
# Processing Record 37 of Set 8 | malanje
# Processing Record 38 of Set 8 | bras-panon
# Processing Record 39 of Set 8 | giresun
# Processing Record 40 of Set 8 | sola
# Processing Record 41 of Set 8 | novopokrovka
# Processing Record 42 of Set 8 | panaba
# Processing Record 43 of Set 8 | linhares
# Processing Record 44 of Set 8 | nangong
# Processing Record 45 of Set 8 | utica
# Processing Record 46 of Set 8 | harper
# Processing Record 47 of Set 8 | babanusah
# City not found. Skipping...
# Processing Record 48 of Set 8 | hofn
# Processing Record 49 of Set 8 | puerto quijarro
# Processing Record 50 of Set 8 | dicabisagan
# Processing Record 1 of Set 9 | pangnirtung
# Processing Record 2 of Set 9 | havoysund
# Processing Record 3 of Set 9 | londiani
# Processing Record 4 of Set 9 | dongsheng
# Processing Record 5 of Set 9 | batemans bay
# Processing Record 6 of Set 9 | jining
# Processing Record 7 of Set 9 | rio grande
# Processing Record 8 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 9 of Set 9 | sao joao da barra
# Processing Record 10 of Set 9 | hebertville
# City not found. Skipping...
# Processing Record 11 of Set 9 | luba
# Processing Record 12 of Set 9 | dvinskoy
# Processing Record 13 of Set 9 | tambura
# Processing Record 14 of Set 9 | portland
# Processing Record 15 of Set 9 | klyuchi
# Processing Record 16 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 17 of Set 9 | richards bay
# Processing Record 18 of Set 9 | cabedelo
# Processing Record 19 of Set 9 | adrar
# Processing Record 20 of Set 9 | shu
# Processing Record 21 of Set 9 | vestmannaeyjar
# Processing Record 22 of Set 9 | saint-francois
# Processing Record 23 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 9 | rocha
# Processing Record 25 of Set 9 | tatarskaya pishlya
# Processing Record 26 of Set 9 | beyneu
# Processing Record 27 of Set 9 | jinchengjiang
# City not found. Skipping...
# Processing Record 28 of Set 9 | campbellton
# Processing Record 29 of Set 9 | charters towers
# Processing Record 30 of Set 9 | sakaiminato
# Processing Record 31 of Set 9 | coquimbo
# Processing Record 32 of Set 9 | porto novo
# Processing Record 33 of Set 9 | luderitz
# Processing Record 34 of Set 9 | nikolskoye
# Processing Record 35 of Set 9 | alekseyevsk
# Processing Record 36 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 37 of Set 9 | zyryanka
# Processing Record 38 of Set 9 | sovetskiy
# Processing Record 39 of Set 9 | bafq
# Processing Record 40 of Set 9 | lasa
# Processing Record 41 of Set 9 | bontang
# Processing Record 42 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 43 of Set 9 | paamiut
# Processing Record 44 of Set 9 | fare
# Processing Record 45 of Set 9 | dondo
# Processing Record 46 of Set 9 | hamilton
# Processing Record 47 of Set 9 | huambo
# Processing Record 48 of Set 9 | nyaunglebin
# Processing Record 49 of Set 9 | luancheng
# Processing Record 50 of Set 9 | nuuk
# Processing Record 1 of Set 10 | bolshaya atnya
# City not found. Skipping...
# Processing Record 2 of Set 10 | sitka
# Processing Record 3 of Set 10 | talnakh
# Processing Record 4 of Set 10 | mackay
# Processing Record 5 of Set 10 | buala
# Processing Record 6 of Set 10 | tateyama
# Processing Record 7 of Set 10 | farnham
# Processing Record 8 of Set 10 | mayo
# Processing Record 9 of Set 10 | gharb
# City not found. Skipping...
# Processing Record 10 of Set 10 | bathsheba
# Processing Record 11 of Set 10 | chimbote
# Processing Record 12 of Set 10 | poum
# Processing Record 13 of Set 10 | loviisa
# Processing Record 14 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 15 of Set 10 | talara
# Processing Record 16 of Set 10 | lucapa
# Processing Record 17 of Set 10 | mbigou
# Processing Record 18 of Set 10 | aden
# Processing Record 19 of Set 10 | olafsvik
# Processing Record 20 of Set 10 | yerbogachen
# Processing Record 21 of Set 10 | saint-georges
# Processing Record 22 of Set 10 | tuatapere
# Processing Record 23 of Set 10 | turan
# Processing Record 24 of Set 10 | hindaun
# Processing Record 25 of Set 10 | grand-santi
# Processing Record 26 of Set 10 | leh
# Processing Record 27 of Set 10 | nagod
# Processing Record 28 of Set 10 | verkhnevilyuysk
# Processing Record 29 of Set 10 | long xuyen
# Processing Record 30 of Set 10 | souillac
# Processing Record 31 of Set 10 | kumluca
# Processing Record 32 of Set 10 | salinas
# Processing Record 33 of Set 10 | vilhena
# Processing Record 34 of Set 10 | ouricuri
# Processing Record 35 of Set 10 | pirojpur
# Processing Record 36 of Set 10 | samarai
# Processing Record 37 of Set 10 | galveston
# Processing Record 38 of Set 10 | linfen
# Processing Record 39 of Set 10 | jalu
# Processing Record 40 of Set 10 | abu samrah
# Processing Record 41 of Set 10 | vila velha
# Processing Record 42 of Set 10 | kaifeng
# Processing Record 43 of Set 10 | labytnangi
# Processing Record 44 of Set 10 | come
# Processing Record 45 of Set 10 | xam nua
# Processing Record 46 of Set 10 | beringovskiy
# Processing Record 47 of Set 10 | port macquarie
# Processing Record 48 of Set 10 | the valley
# Processing Record 49 of Set 10 | ulladulla
# Processing Record 50 of Set 10 | fano
# Processing Record 1 of Set 11 | morondava
# Processing Record 2 of Set 11 | stonewall
# Processing Record 3 of Set 11 | camana
# Processing Record 4 of Set 11 | boyabat
# Processing Record 5 of Set 11 | kamiiso
# Processing Record 6 of Set 11 | aljezur
# Processing Record 7 of Set 11 | sri aman
# Processing Record 8 of Set 11 | sorland
# Processing Record 9 of Set 11 | cotonou
# Processing Record 10 of Set 11 | fortuna
# Processing Record 11 of Set 11 | la maddalena
# Processing Record 12 of Set 11 | morro bay
# Processing Record 13 of Set 11 | youkounkoun
# Processing Record 14 of Set 11 | zanesville
# Processing Record 15 of Set 11 | xuddur
# Processing Record 16 of Set 11 | novikovo
# Processing Record 17 of Set 11 | ushibuka
# Processing Record 18 of Set 11 | harnosand
# Processing Record 19 of Set 11 | andenes
# Processing Record 20 of Set 11 | anadyr
# Processing Record 21 of Set 11 | halifax
# Processing Record 22 of Set 11 | buqayq
# City not found. Skipping...
# Processing Record 23 of Set 11 | sorong
# Processing Record 24 of Set 11 | kargasok
# Processing Record 25 of Set 11 | bismarck
# Processing Record 26 of Set 11 | kondinskoye
# Processing Record 27 of Set 11 | hewitt
# Processing Record 28 of Set 11 | bayanday
# Processing Record 29 of Set 11 | outjo
# Processing Record 30 of Set 11 | scottsburgh
# City not found. Skipping...
# Processing Record 31 of Set 11 | krasnohrad
# Processing Record 32 of Set 11 | atar
# Processing Record 33 of Set 11 | bagdarin
# Processing Record 34 of Set 11 | gebre guracha
# Processing Record 35 of Set 11 | port moresby
# Processing Record 36 of Set 11 | kilindoni
# Processing Record 37 of Set 11 | hinton
# Processing Record 38 of Set 11 | ponta delgada
# Processing Record 39 of Set 11 | bridgetown
# Processing Record 40 of Set 11 | barbalha
# Processing Record 41 of Set 11 | urdzhar
# City not found. Skipping...
# Processing Record 42 of Set 11 | ileza
# Processing Record 43 of Set 11 | namatanai
# Processing Record 44 of Set 11 | ahuimanu
# Processing Record 45 of Set 11 | nalut
# Processing Record 46 of Set 11 | marzuq
# Processing Record 47 of Set 11 | guilin
# Processing Record 48 of Set 11 | lagos
# Processing Record 49 of Set 11 | roros
# Processing Record 50 of Set 11 | kununurra
# Processing Record 1 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 12 | luganville
# Processing Record 3 of Set 12 | kruisfontein
# Processing Record 4 of Set 12 | nerchinskiy zavod
# Processing Record 5 of Set 12 | smithers
# Processing Record 6 of Set 12 | itoman
# Processing Record 7 of Set 12 | inhambane
# Processing Record 8 of Set 12 | sao sebastiao
# Processing Record 9 of Set 12 | vengerovo
# Processing Record 10 of Set 12 | inowroclaw
# Processing Record 11 of Set 12 | paita
# Processing Record 12 of Set 12 | lazaro cardenas
# Processing Record 13 of Set 12 | chapada dos guimaraes
# Processing Record 14 of Set 12 | egvekinot
# Processing Record 15 of Set 12 | conceicao da barra
# Processing Record 16 of Set 12 | sakakah
# Processing Record 17 of Set 12 | abu zabad
# Processing Record 18 of Set 12 | petatlan
# Processing Record 19 of Set 12 | japura
# Processing Record 20 of Set 12 | tonneins
# Processing Record 21 of Set 12 | kokopo
# Processing Record 22 of Set 12 | eyl
# Processing Record 23 of Set 12 | sorgun
# Processing Record 24 of Set 12 | bulawayo
# Processing Record 25 of Set 12 | athabasca
# Processing Record 26 of Set 12 | tilichiki
# Processing Record 27 of Set 12 | trinidad
# Processing Record 28 of Set 12 | kayerkan
# Processing Record 29 of Set 12 | puerto madryn
# Processing Record 30 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 32 of Set 12 | pochutla
# Processing Record 33 of Set 12 | tsogni
# Processing Record 34 of Set 12 | kampot
# Processing Record 35 of Set 12 | jiuquan
# Processing Record 36 of Set 12 | aykhal
# Processing Record 37 of Set 12 | colmenar viejo
# Processing Record 38 of Set 12 | bom jardim
# Processing Record 39 of Set 12 | xining
# Processing Record 40 of Set 12 | balta
# Processing Record 41 of Set 12 | sahrak
# City not found. Skipping...
# Processing Record 42 of Set 12 | yulara
# Processing Record 43 of Set 12 | khrebtovaya
# Processing Record 44 of Set 12 | sechura
# Processing Record 45 of Set 12 | show low
# Processing Record 46 of Set 12 | melville
# Processing Record 47 of Set 12 | kawalu
# Processing Record 48 of Set 12 | lodja
# Processing Record 49 of Set 12 | port shepstone
# Processing Record 50 of Set 12 | caruray
# Processing Record 1 of Set 13 | cascais
# Processing Record 2 of Set 13 | faya
# Processing Record 3 of Set 13 | moyale
# Processing Record 4 of Set 13 | port hedland
# Processing Record 5 of Set 13 | artyom
# Processing Record 6 of Set 13 | ziro
# Processing Record 7 of Set 13 | santiago del estero
# Processing Record 8 of Set 13 | chardara
# Processing Record 9 of Set 13 | thio
# Processing Record 10 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 11 of Set 13 | izhma
# Processing Record 12 of Set 13 | uige
# Processing Record 13 of Set 13 | alexander city
# Processing Record 14 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 15 of Set 13 | lata
# Processing Record 16 of Set 13 | havre-saint-pierre
# Processing Record 17 of Set 13 | solnechnyy
# Processing Record 18 of Set 13 | ahipara
# Processing Record 19 of Set 13 | diapaga
# Processing Record 20 of Set 13 | nadvoitsy
# Processing Record 21 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 22 of Set 13 | hoopstad
# Processing Record 23 of Set 13 | mwense
# Processing Record 24 of Set 13 | husavik
# Processing Record 25 of Set 13 | zhuanghe
# Processing Record 26 of Set 13 | tabuk
# Processing Record 27 of Set 13 | kieta
# Processing Record 28 of Set 13 | ubinskoye
# Processing Record 29 of Set 13 | buraydah
# Processing Record 30 of Set 13 | iroquois falls
# Processing Record 31 of Set 13 | millinocket
# Processing Record 32 of Set 13 | zhigansk
# Processing Record 33 of Set 13 | tocopilla
# Processing Record 34 of Set 13 | fairbanks
# Processing Record 35 of Set 13 | auki
# Processing Record 36 of Set 13 | adamovka
# Processing Record 37 of Set 13 | krasnyy yar
# Processing Record 38 of Set 13 | presidencia roque saenz pena
# Processing Record 39 of Set 13 | tawang
# Processing Record 40 of Set 13 | igra
# Processing Record 41 of Set 13 | huanren
# Processing Record 42 of Set 13 | kifri
# Processing Record 43 of Set 13 | meridian
# Processing Record 44 of Set 13 | plouzane
# Processing Record 45 of Set 13 | potam
# Processing Record 46 of Set 13 | sukhobezvodnoye
# Processing Record 47 of Set 13 | dayong
# Processing Record 48 of Set 13 | porto tolle
# Processing Record 49 of Set 13 | muroto
# Processing Record 50 of Set 13 | baiyin
# Processing Record 1 of Set 14 | ural
# Processing Record 2 of Set 14 | zaysan
# Processing Record 3 of Set 14 | gamba
# Processing Record 4 of Set 14 | tecpan
# Processing Record 5 of Set 14 | torbay
# Processing Record 6 of Set 14 | berezovyy
# Processing Record 7 of Set 14 | sundumbili
# Processing Record 8 of Set 14 | tessalit
# Processing Record 9 of Set 14 | tezu
# Processing Record 10 of Set 14 | kuyanovo
# Processing Record 11 of Set 14 | mogadishu
# Processing Record 12 of Set 14 | hualmay
# Processing Record 13 of Set 14 | madison
# Processing Record 14 of Set 14 | kacergine
# City not found. Skipping...
# Processing Record 15 of Set 14 | shchelyayur
# City not found. Skipping...
# Processing Record 16 of Set 14 | puerto rondon
# Processing Record 17 of Set 14 | la primavera
# Processing Record 18 of Set 14 | amarillo
# Processing Record 19 of Set 14 | uaua
# Processing Record 20 of Set 14 | wanning
# Processing Record 21 of Set 14 | lumut
# Processing Record 22 of Set 14 | san ramon
# Processing Record 23 of Set 14 | lubumbashi
# Processing Record 24 of Set 14 | portobelo
# Processing Record 25 of Set 14 | fuxin
# Processing Record 26 of Set 14 | itarema
# Processing Record 27 of Set 14 | warrington
# Processing Record 28 of Set 14 | asyut
# Processing Record 29 of Set 14 | raton
# Processing Record 30 of Set 14 | tsabong
# Processing Record 31 of Set 14 | safaga
# Processing Record 32 of Set 14 | oxford
# Processing Record 33 of Set 14 | balkanabat
# Processing Record 34 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 35 of Set 14 | kushmurun
# Processing Record 36 of Set 14 | grindavik
# Processing Record 37 of Set 14 | jumla
# Processing Record 38 of Set 14 | finschhafen
# Processing Record 39 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 40 of Set 14 | mujiayingzi
# Processing Record 41 of Set 14 | tabou
# Processing Record 42 of Set 14 | krasnoselkup
# Processing Record 43 of Set 14 | boundiali
# Processing Record 44 of Set 14 | banikoara
# Processing Record 45 of Set 14 | bay roberts
# Processing Record 46 of Set 14 | nishihara
# Processing Record 47 of Set 14 | churapcha
# Processing Record 48 of Set 14 | yarada
# Processing Record 49 of Set 14 | sisimiut
# Processing Record 50 of Set 14 | anupgarh
# Processing Record 1 of Set 15 | brunico
# Processing Record 2 of Set 15 | haines junction
# Processing Record 3 of Set 15 | mansa
# Processing Record 4 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 15 | maniitsoq
# Processing Record 6 of Set 15 | illela
# Processing Record 7 of Set 15 | bronnoysund
# Processing Record 8 of Set 15 | ixtapa
# Processing Record 9 of Set 15 | sosnovo-ozerskoye
# Processing Record 10 of Set 15 | yefimovskiy
# City not found. Skipping...
# Processing Record 11 of Set 15 | ulagan
# Processing Record 12 of Set 15 | te anau
# Processing Record 13 of Set 15 | ingraj bazar
# Processing Record 14 of Set 15 | gua musang
# Processing Record 15 of Set 15 | alta floresta
# Processing Record 16 of Set 15 | tutoia
# Processing Record 17 of Set 15 | horsham
# Processing Record 18 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 19 of Set 15 | bubaque
# Processing Record 20 of Set 15 | fukue
# Processing Record 21 of Set 15 | kumba
# Processing Record 22 of Set 15 | vallenar
# Processing Record 23 of Set 15 | ranong
# Processing Record 24 of Set 15 | kamloops
# Processing Record 25 of Set 15 | henties bay
# Processing Record 26 of Set 15 | tucurui
# Processing Record 27 of Set 15 | longview
# Processing Record 28 of Set 15 | suzu
# City not found. Skipping...
# Processing Record 29 of Set 15 | golden gate
# Processing Record 30 of Set 15 | inuvik
# Processing Record 31 of Set 15 | nioro
# Processing Record 32 of Set 15 | angoram
# Processing Record 33 of Set 15 | mega
# Processing Record 34 of Set 15 | greymouth
# Processing Record 35 of Set 15 | tongren
# Processing Record 36 of Set 15 | qaqortoq
# Processing Record 37 of Set 15 | peace river
# Processing Record 38 of Set 15 | poronaysk
# Processing Record 39 of Set 15 | santa barbara
# Processing Record 40 of Set 15 | qandala
# Processing Record 41 of Set 15 | caramay
# Processing Record 42 of Set 15 | tunceli
# Processing Record 43 of Set 15 | bilma
# Processing Record 44 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 45 of Set 15 | yuryevets
# Processing Record 46 of Set 15 | canchungo
# Processing Record 47 of Set 15 | pryazha
# Processing Record 48 of Set 15 | havelock
# Processing Record 49 of Set 15 | zeya
# Processing Record 50 of Set 15 | waddan
# Processing Record 1 of Set 16 | coro
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 686

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                Marawi   7.9986  124.2928     68.76        92          83
# 1              Klaksvik  62.2266   -6.5890     49.12        84          36
# 2  Vila Franca Do Campo  37.7167  -25.4333     73.81        86          49
# 3           Broken Hill -31.9500  141.4333     42.44        82           0
# 4               Ushuaia -54.8000  -68.3000     35.22        86          40
# 5                 Vitim  59.4511  112.5578     66.69        84           9
# 6           San Vicente -26.6167  -54.1333     68.49        67           0
# 7                 Bluff -46.6000  168.3333     44.80        89         100
# 8           Provideniya  64.3833 -173.3000     48.31        71         100
# 9              Hermanus -34.4187   19.2345     52.81        62           0
#
#    Wind Speed Country Current Description                 Date
# 0        4.32      PH       broken clouds  2022-07-25 20:59:37
# 1       14.32      FO    scattered clouds  2022-07-25 20:59:38
# 2        3.76      PT    scattered clouds  2022-07-25 20:59:38
# 3       12.08      AU           clear sky  2022-07-25 20:59:39
# 4       26.46      AR          light snow  2022-07-25 20:59:39
# 5        3.09      RU           clear sky  2022-07-25 20:59:40
# 6        1.45      AR           clear sky  2022-07-25 20:55:33
# 7       27.69      NZ          light rain  2022-07-25 20:59:41
# 8       13.42      RU     overcast clouds  2022-07-25 20:59:41
# 9        8.39      ZA           clear sky  2022-07-25 20:59:42

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                    City Country      Lat       Lng  Max Temp  Humidity  \
# 0                Marawi      PH   7.9986  124.2928     68.76        92
# 1              Klaksvik      FO  62.2266   -6.5890     49.12        84
# 2  Vila Franca Do Campo      PT  37.7167  -25.4333     73.81        86
# 3           Broken Hill      AU -31.9500  141.4333     42.44        82
# 4               Ushuaia      AR -54.8000  -68.3000     35.22        86
# 5                 Vitim      RU  59.4511  112.5578     66.69        84
# 6           San Vicente      AR -26.6167  -54.1333     68.49        67
# 7                 Bluff      NZ -46.6000  168.3333     44.80        89
# 8           Provideniya      RU  64.3833 -173.3000     48.31        71
# 9              Hermanus      ZA -34.4187   19.2345     52.81        62
#
#    Cloudiness  Wind Speed Current Description
# 0          83        4.32       broken clouds
# 1          36       14.32    scattered clouds
# 2          49        3.76    scattered clouds
# 3           0       12.08           clear sky
# 4          40       26.46          light snow
# 5           9        3.09           clear sky
# 6           0        1.45           clear sky
# 7         100       27.69          light rain
# 8         100       13.42     overcast clouds
# 9           0        8.39           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
